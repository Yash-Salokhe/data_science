# %%
import pandas as pd
import numpy as np
import keras
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential 
from keras.layers import Dense
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import GridSearchCV, KFold

from tensorflow import keras
from keras.layers import Dense
from keras.layers import Dropout
from keras.optimizers import Adam
from tensorflow.keras import layers
from keras.models import Sequential
from keras.wrappers.scikit_learn import KerasClassifier, KerasRegressor

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('gas_turbines.csv')
df
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# 0      3.1547  82.722
# 1      3.2363  82.776
# 2      3.2012  82.468
# 3      3.1923  82.670
# 4      3.2484  82.311
# ...       ...     ...
# 15034  4.5186  79.559
# 15035  4.8470  79.917
# 15036  7.9632  90.912
# 15037  6.2494  93.227
# 15038  4.9816  92.498
#
# [15039 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   AFDP    15039 non-null  float64
#  4   GTEP    15039 non-null  float64
#  5   TIT     15039 non-null  float64
#  6   TAT     15039 non-null  float64
#  7   TEY     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [AT, AP, AH, AFDP, GTEP, TIT, TAT, TEY, CDP, CO, NOX]
# Index: []

# %%
df.describe()
# Out:
#                  AT           AP            AH          AFDP          GTEP  \
# count  15039.000000  15039.00000  15039.000000  15039.000000  15039.000000
# mean      17.764381   1013.19924     79.124174      4.200294     25.419061
# std        7.574323      6.41076     13.793439      0.760197      4.173916
# min        0.522300    985.85000     30.344000      2.087400     17.878000
# 25%       11.408000   1008.90000     69.750000      3.723900     23.294000
# 50%       18.186000   1012.80000     82.266000      4.186200     25.082000
# 75%       23.862500   1016.90000     90.043500      4.550900     27.184000
# max       34.929000   1034.20000    100.200000      7.610600     37.402000
#
#                 TIT           TAT           TEY           CDP            CO  \
# count  15039.000000  15039.000000  15039.000000  15039.000000  15039.000000
# mean    1083.798770    545.396183    134.188464     12.102353      1.972499
# std       16.527806      7.866803     15.829717      1.103196      2.222206
# min     1000.800000    512.450000    100.170000      9.904400      0.000388
# 25%     1079.600000    542.170000    127.985000     11.622000      0.858055
# 50%     1088.700000    549.890000    133.780000     12.025000      1.390200
# 75%     1096.000000    550.060000    140.895000     12.578000      2.160400
# max     1100.800000    550.610000    174.610000     15.081000     44.103000
#
#                 NOX
# count  15039.000000
# mean      68.190934
# std       10.470586
# min       27.765000
# 25%       61.303500
# 50%       66.601000
# 75%       73.935500
# max      119.890000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
figure = plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
#selecting best features
from numpy import set_printoptions
from sklearn.feature_selection import mutual_info_regression

# %%
x = df.drop(['TEY'], axis=1)
y = df[['TEY']]

# %%
best_features = SelectKBest(score_func=mutual_info_regression, k='all')
fit = best_features.fit(x,y)

# %%
scores = fit.scores_
features = fit.transform(x)

# %%
scores_df = pd.DataFrame(list(zip(scores, x.columns)), columns=['Score','Feature'])
scores_df.sort_values(by='Score', ascending = False, inplace=True)
scores_df
# Out:
#       Score Feature
# 7  1.712152     CDP
# 4  1.600026    GTEP
# 5  1.324560     TIT
# 6  0.895809     TAT
# 3  0.659942    AFDP
# 8  0.512802      CO
# 0  0.412319      AT
# 9  0.300475     NOX
# 1  0.139750      AP
# 2  0.097938      AH

# %%
df2 = df[['CDP', 'GTEP','TIT', 'TAT', 'AFDP', 'CO', 'AT','TEY']]
df2.head()
# Out:
#       CDP    GTEP     TIT     TAT    AFDP      CO      AT     TEY
# 0  10.605  19.663  1059.2  550.00  3.5000  3.1547  6.8594  114.70
# 1  10.598  19.728  1059.3  550.00  3.4998  3.2363  6.7850  114.72
# 2  10.601  19.779  1059.4  549.87  3.4824  3.2012  6.8977  114.71
# 3  10.606  19.792  1059.6  549.99  3.4805  3.1923  7.0569  114.72
# 4  10.612  19.765  1059.7  549.98  3.4976  3.2484  7.3978  114.72

# %%
#applying standardScalar
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df2.values)
df_new = pd.DataFrame(df_scaled, columns=[df2.columns])
df_new
# Out:
#             CDP      GTEP       TIT       TAT      AFDP        CO        AT  \
# 0     -1.357331 -1.379101 -1.488376  0.585240 -0.921232  0.532012 -1.439778
# 1     -1.363676 -1.363528 -1.482325  0.585240 -0.921495  0.568733 -1.449601
# 2     -1.360957 -1.351309 -1.476275  0.568715 -0.944385  0.552938 -1.434721
# 3     -1.356424 -1.348194 -1.464173  0.583969 -0.946884  0.548933 -1.413702
# 4     -1.350985 -1.354663 -1.458123  0.582698 -0.924389  0.574179 -1.368693
# ...         ...       ...       ...       ...       ...       ...       ...
# 15034 -1.543161 -1.498657 -2.063184  0.103453 -0.865850  1.145792 -1.153182
# 15035 -1.513247 -1.438759 -2.268905 -0.276638 -0.913470  1.293578 -1.303986
# 15036 -1.467922 -1.410967 -2.789257 -1.026650 -0.951488  2.695925 -1.386267
# 15037 -1.422598 -1.447624 -2.456474 -0.528337 -0.988848  1.924683 -1.420423
# 15038 -1.377273 -1.464635 -2.051083  0.057689 -1.016605  1.354150 -1.430734
#
#             TEY
# 0     -1.231172
# 1     -1.229909
# 2     -1.230541
# 3     -1.229909
# 4     -1.229909
# ...         ...
# 15034 -1.426381
# 15035 -1.415642
# 15036 -1.516089
# 15037 -1.481343
# 15038 -1.428277
#
# [15039 rows x 8 columns]

# %%
df_new.describe()
# Out:
#                 CDP          GTEP           TIT           TAT          AFDP  \
# count  1.503900e+04  1.503900e+04  1.503900e+04  1.503900e+04  1.503900e+04
# mean   3.640356e-16  1.107344e-16 -2.324212e-15  1.744899e-15  3.810001e-16
# std    1.000033e+00  1.000033e+00  1.000033e+00  1.000033e+00  1.000033e+00
# min   -1.992416e+00 -1.806771e+00 -5.021933e+00 -4.188141e+00 -2.779497e+00
# 25%   -4.354335e-01 -5.091458e-01 -2.540512e-01 -4.101146e-01 -6.266930e-01
# 50%   -7.011925e-02 -8.075681e-02  2.965544e-01  5.712570e-01 -1.854065e-02
# 75%    4.311680e-01  4.228638e-01  7.382490e-01  5.928675e-01  4.612196e-01
# max    2.700105e+00  2.871006e+00  1.028678e+00  6.627839e-01  4.486233e+00
#
#                  CO            AT           TEY
# count  1.503900e+04  1.503900e+04  1.503900e+04
# mean   1.953355e-17 -2.320107e-16  1.406445e-15
# std    1.000033e+00  1.000033e+00  1.000033e+00
# min   -8.874862e-01 -2.276462e+00 -2.149097e+00
# 25%   -5.015202e-01 -8.392292e-01 -3.919003e-01
# 50%   -2.620452e-01  5.566605e-02 -2.580448e-02
# 75%    8.455882e-02  8.051309e-01  4.236815e-01
# max    1.895949e+01  2.266234e+00  2.553607e+00

# %%
x = df_new.drop(['TEY'], axis=1)
y = df_new[['TEY']]

# %%
# Create model
model = Sequential()
model.add(Dense(12, input_dim=7,  activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='mean_squared_error', optimizer='adam', metrics=["mean_absolute_error"])

# %%
results= model.fit(x, y, validation_split=0.2, epochs= 100, batch_size=10 )
# Out:
# Epoch 1/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5779 - mean_absolute_error: 0.5243 - val_loss: 0.6841 - val_mean_absolute_error: 0.5557
# Epoch 2/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5298 - mean_absolute_error: 0.4605 - val_loss: 0.6833 - val_mean_absolute_error: 0.5528
# Epoch 3/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5288 - mean_absolute_error: 0.4574 - val_loss: 0.6826 - val_mean_absolute_error: 0.5503
# Epoch 4/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5282 - mean_absolute_error: 0.4554 - val_loss: 0.6822 - val_mean_absolute_error: 0.5492
# Epoch 5/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5278 - mean_absolute_error: 0.4541 - val_loss: 0.6826 - val_mean_absolute_error: 0.5512
# Epoch 6/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5277 - mean_absolute_error: 0.4533 - val_loss: 0.6819 - val_mean_absolute_error: 0.5481
# Epoch 7/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5275 - mean_absolute_error: 0.4528 - val_loss: 0.6818 - val_mean_absolute_error: 0.5474
# Epoch 8/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5275 - mean_absolute_error: 0.4524 - val_loss: 0.6818 - val_mean_absolute_error: 0.5472
# Epoch 9/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5274 - mean_absolute_error: 0.4522 - val_loss: 0.6817 - val_mean_absolute_error: 0.5469
# Epoch 10/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5274 - mean_absolute_error: 0.4520 - val_loss: 0.6818 - val_mean_absolute_error: 0.5470
# Epoch 11/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5274 - mean_absolute_error: 0.4518 - val_loss: 0.6819 - val_mean_absolute_error: 0.5475
# Epoch 12/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5274 - mean_absolute_error: 0.4515 - val_loss: 0.6818 - val_mean_absolute_error: 0.5473
# Epoch 13/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5274 - mean_absolute_error: 0.4515 - val_loss: 0.6819 - val_mean_absolute_error: 0.5478
# Epoch 14/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5273 - mean_absolute_error: 0.4515 - val_loss: 0.6817 - val_mean_absolute_error: 0.5465
# Epoch 15/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5273 - mean_absolute_error: 0.4512 - val_loss: 0.6817 - val_mean_absolute_error: 0.5465
# Epoch 16/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5273 - mean_absolute_error: 0.4512 - val_loss: 0.6818 - val_mean_absolute_error: 0.5468
# Epoch 17/100
# 1204/1204 [==============================] - 2s 2ms/step - loss: 0.5273 - mean_absolute_error: 0.4511 - val_loss: 0.6816 - val_mean_absolute_error: 0.5462
# Epoch 18/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5273 - mean_absolute_error: 0.4509 - val_loss: 0.6817 - val_mean_absolute_error: 0.5462
# Epoch 19/100
# 1204/1204 [==============================] - 2s 2ms/step - loss: 0.5273 - mean_absolute_error: 0.4509 - val_loss: 0.6817 - val_mean_absolute_error: 0.5464
# Epoch 20/100
# 1204/1204 [==============================] - 2s 2ms/step - loss: 0.5273 - mean_absolute_error: 0.4509 - val_loss: 0.6816 - val_mean_absolute_error: 0.5457
# Epoch 21/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5273 - mean_absolute_error: 0.4508 - val_loss: 0.6816 - val_mean_absolute_error: 0.5455
# Epoch 22/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5272 - mean_absolute_error: 0.4507 - val_loss: 0.6816 - val_mean_absolute_error: 0.5456
# Epoch 23/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5272 - mean_absolute_error: 0.4506 - val_loss: 0.6816 - val_mean_absolute_error: 0.5454
# Epoch 24/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5272 - mean_absolute_error: 0.4505 - val_loss: 0.6820 - val_mean_absolute_error: 0.5484
# Epoch 25/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5272 - mean_absolute_error: 0.4505 - val_loss: 0.6815 - val_mean_absolute_error: 0.5450
# Epoch 26/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5272 - mean_absolute_error: 0.4504 - val_loss: 0.6815 - val_mean_absolute_error: 0.5451
# Epoch 27/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5272 - mean_absolute_error: 0.4503 - val_loss: 0.6816 - val_mean_absolute_error: 0.5454
# Epoch 28/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4502 - val_loss: 0.6815 - val_mean_absolute_error: 0.5451
# Epoch 29/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4503 - val_loss: 0.6815 - val_mean_absolute_error: 0.5450
# Epoch 30/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4502 - val_loss: 0.6815 - val_mean_absolute_error: 0.5447
# Epoch 31/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4501 - val_loss: 0.6815 - val_mean_absolute_error: 0.5449
# Epoch 32/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4500 - val_loss: 0.6815 - val_mean_absolute_error: 0.5447
# Epoch 33/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4501 - val_loss: 0.6818 - val_mean_absolute_error: 0.5472
# Epoch 34/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4500 - val_loss: 0.6814 - val_mean_absolute_error: 0.5447
# Epoch 35/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4500 - val_loss: 0.6818 - val_mean_absolute_error: 0.5471
# Epoch 36/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4500 - val_loss: 0.6815 - val_mean_absolute_error: 0.5453
# Epoch 37/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4500 - val_loss: 0.6814 - val_mean_absolute_error: 0.5446
# Epoch 38/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4499 - val_loss: 0.6815 - val_mean_absolute_error: 0.5449
# Epoch 39/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4500 - val_loss: 0.6817 - val_mean_absolute_error: 0.5466
# Epoch 40/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4499 - val_loss: 0.6816 - val_mean_absolute_error: 0.5454
# Epoch 41/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4499 - val_loss: 0.6814 - val_mean_absolute_error: 0.5447
# Epoch 42/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4499 - val_loss: 0.6816 - val_mean_absolute_error: 0.5456
# Epoch 43/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4498 - val_loss: 0.6815 - val_mean_absolute_error: 0.5449
# Epoch 44/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4499 - val_loss: 0.6814 - val_mean_absolute_error: 0.5443
# Epoch 45/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4498 - val_loss: 0.6815 - val_mean_absolute_error: 0.5451
# Epoch 46/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4498 - val_loss: 0.6814 - val_mean_absolute_error: 0.5444
# Epoch 47/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4499 - val_loss: 0.6815 - val_mean_absolute_error: 0.5449
# Epoch 48/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4499 - val_loss: 0.6815 - val_mean_absolute_error: 0.5457
# Epoch 49/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4497 - val_loss: 0.6815 - val_mean_absolute_error: 0.5452
# Epoch 50/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4498 - val_loss: 0.6814 - val_mean_absolute_error: 0.5444
# Epoch 51/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4498 - val_loss: 0.6815 - val_mean_absolute_error: 0.5455
# Epoch 52/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4498 - val_loss: 0.6814 - val_mean_absolute_error: 0.5446
# Epoch 53/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4498 - val_loss: 0.6815 - val_mean_absolute_error: 0.5451
# Epoch 54/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4497 - val_loss: 0.6817 - val_mean_absolute_error: 0.5464
# Epoch 55/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4497 - val_loss: 0.6815 - val_mean_absolute_error: 0.5452
# Epoch 56/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4497 - val_loss: 0.6815 - val_mean_absolute_error: 0.5448
# Epoch 57/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4498 - val_loss: 0.6815 - val_mean_absolute_error: 0.5451
# Epoch 58/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4497 - val_loss: 0.6815 - val_mean_absolute_error: 0.5450
# Epoch 59/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4497 - val_loss: 0.6815 - val_mean_absolute_error: 0.5453
# Epoch 60/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4497 - val_loss: 0.6815 - val_mean_absolute_error: 0.5449
# Epoch 61/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4497 - val_loss: 0.6814 - val_mean_absolute_error: 0.5446
# Epoch 62/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4497 - val_loss: 0.6815 - val_mean_absolute_error: 0.5450
# Epoch 63/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4496 - val_loss: 0.6814 - val_mean_absolute_error: 0.5444
# Epoch 64/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4496 - val_loss: 0.6815 - val_mean_absolute_error: 0.5447
# Epoch 65/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4497 - val_loss: 0.6815 - val_mean_absolute_error: 0.5453
# Epoch 66/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4496 - val_loss: 0.6814 - val_mean_absolute_error: 0.5447
# Epoch 67/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4497 - val_loss: 0.6815 - val_mean_absolute_error: 0.5449
# Epoch 68/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4496 - val_loss: 0.6814 - val_mean_absolute_error: 0.5444
# Epoch 69/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4497 - val_loss: 0.6814 - val_mean_absolute_error: 0.5443
# Epoch 70/100
# 1204/1204 [==============================] - 2s 2ms/step - loss: 0.5270 - mean_absolute_error: 0.4496 - val_loss: 0.6814 - val_mean_absolute_error: 0.5445
# Epoch 71/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4497 - val_loss: 0.6814 - val_mean_absolute_error: 0.5446
# Epoch 72/100
# 1204/1204 [==============================] - 2s 2ms/step - loss: 0.5270 - mean_absolute_error: 0.4496 - val_loss: 0.6814 - val_mean_absolute_error: 0.5446
# Epoch 73/100
# 1204/1204 [==============================] - 2s 2ms/step - loss: 0.5270 - mean_absolute_error: 0.4496 - val_loss: 0.6815 - val_mean_absolute_error: 0.5448
# Epoch 74/100
# 1204/1204 [==============================] - 2s 2ms/step - loss: 0.5270 - mean_absolute_error: 0.4497 - val_loss: 0.6814 - val_mean_absolute_error: 0.5446
# Epoch 75/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4497 - val_loss: 0.6815 - val_mean_absolute_error: 0.5449
# Epoch 76/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4496 - val_loss: 0.6814 - val_mean_absolute_error: 0.5446
# Epoch 77/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5271 - mean_absolute_error: 0.4497 - val_loss: 0.6814 - val_mean_absolute_error: 0.5445
# Epoch 78/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4497 - val_loss: 0.6814 - val_mean_absolute_error: 0.5444
# Epoch 79/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4497 - val_loss: 0.6816 - val_mean_absolute_error: 0.5457
# Epoch 80/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4496 - val_loss: 0.6815 - val_mean_absolute_error: 0.5449
# Epoch 81/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4496 - val_loss: 0.6814 - val_mean_absolute_error: 0.5444
# Epoch 82/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4496 - val_loss: 0.6814 - val_mean_absolute_error: 0.5444
# Epoch 83/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4496 - val_loss: 0.6814 - val_mean_absolute_error: 0.5446
# Epoch 84/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4497 - val_loss: 0.6814 - val_mean_absolute_error: 0.5445
# Epoch 85/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4495 - val_loss: 0.6814 - val_mean_absolute_error: 0.5444
# Epoch 86/100
# 1204/1204 [==============================] - 2s 2ms/step - loss: 0.5270 - mean_absolute_error: 0.4496 - val_loss: 0.6814 - val_mean_absolute_error: 0.5445
# Epoch 87/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4496 - val_loss: 0.6814 - val_mean_absolute_error: 0.5445
# Epoch 88/100
# 1204/1204 [==============================] - 2s 2ms/step - loss: 0.5270 - mean_absolute_error: 0.4496 - val_loss: 0.6814 - val_mean_absolute_error: 0.5446
# Epoch 89/100
# 1204/1204 [==============================] - 2s 2ms/step - loss: 0.5270 - mean_absolute_error: 0.4496 - val_loss: 0.6816 - val_mean_absolute_error: 0.5456
# Epoch 90/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4496 - val_loss: 0.6814 - val_mean_absolute_error: 0.5446
# Epoch 91/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4496 - val_loss: 0.6814 - val_mean_absolute_error: 0.5443
# Epoch 92/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4496 - val_loss: 0.6814 - val_mean_absolute_error: 0.5444
# Epoch 93/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4497 - val_loss: 0.6814 - val_mean_absolute_error: 0.5442
# Epoch 94/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4496 - val_loss: 0.6814 - val_mean_absolute_error: 0.5445
# Epoch 95/100
# 1204/1204 [==============================] - 2s 2ms/step - loss: 0.5270 - mean_absolute_error: 0.4495 - val_loss: 0.6814 - val_mean_absolute_error: 0.5445
# Epoch 96/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4495 - val_loss: 0.6814 - val_mean_absolute_error: 0.5443
# Epoch 97/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4495 - val_loss: 0.6814 - val_mean_absolute_error: 0.5445
# Epoch 98/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4495 - val_loss: 0.6814 - val_mean_absolute_error: 0.5443
# Epoch 99/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4496 - val_loss: 0.6815 - val_mean_absolute_error: 0.5451
# Epoch 100/100
# 1204/1204 [==============================] - 2s 1ms/step - loss: 0.5270 - mean_absolute_error: 0.4495 - val_loss: 0.6815 - val_mean_absolute_error: 0.5449

# %%
# Model performance
plt.plot(results.history['val_mean_absolute_error'])
plt.plot(results.history['mean_absolute_error'])
plt.title('model performance')
plt.ylabel('MAE')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# History of loss
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# All Hyperparameters at the same time 
#creating model 
def create_model(learning_rate,dropout_rate,activation_function,init,neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 7,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = learning_rate)
    model.compile(loss = 'mean_absolute_error',optimizer = adam,metrics = ['mean_absolute_error'])
    return model

model = KerasRegressor(build_fn = create_model,verbose = 0)

# %%
# Define the grid search parameters

batch_size = [40]
epochs = [100]
learning_rate = [0.1]
dropout_rate = [0.0,0.1,0.2]
activation_function = ['relu','tanh','linear']
init = ['uniform','normal','zero']
neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of the grid search parameters

param_grids = dict(batch_size = batch_size,epochs = epochs,learning_rate = learning_rate,dropout_rate = dropout_rate,
                   activation_function = activation_function,init = init,neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(x,y)

# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# [CV 1/5; 1/243] START activation_function=relu, batch_size=40, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 1/5; 1/243] END activation_function=relu, batch_size=40, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2;, score=-0.589 total time=  29.8s
# [CV 2/5; 1/243] START activation_function=relu, batch_size=40, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 2/5; 1/243] END activation_function=relu, batch_size=40, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2;, score=-0.368 total time=  29.4s
# [CV 3/5; 1/243] START activation_function=relu, batch_size=40, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 3/5; 1/243] END activation_function=relu, batch_size=40, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2;, score=-0.464 total time=  29.0s
# [CV 4/5; 1/243] START activation_function=relu, batch_size=40, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 4/5; 1/243] END activation_function=relu, batch_size=40, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2;, score=-0.448 total time=  29.4s
# [CV 5/5; 1/243] START activation_function=relu, batch_size=40, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 5/5; 1/243] END activation_function=relu, batch_size=40, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2;, score=-0.551 total time=  30.8s
# [CV 1/5; 2/243] START activation_function=relu, batch_size=40, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
